# %% [markdown]
# # GeoJson 資料整理
# ```python
# import time
# from IPython.display import clear_output
# for i in range(100):
#   time.sleep(0.1)
#   print(i)
#   time.sleep(0.5)
#   clear_output()
# ```

# %%
import json
## 爬蟲 抓經緯度資料
from IPython.display import clear_output
import requests
import time
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup

# %% [markdown]
# ## 整理原始資料

# %%
filename = "嘉義縣107.json"
with open(filename,'r') as f:
    data = json.load(f)
print(len(data["data"]))
# Out:
# 2098

# %%
count = 0
modified_data = []
for i in data["data"]:
    try:
        if i["門牌"][0]["號"]!="":
            modified_data.append(i)
            count = count+1
    except:
        pass
print(count)
# Out:
# 838

# %%
key = ['行政區','村里鄰','路街段巷弄','號','樓']
for i in range(0,count):
    address = ""
    for k in key:
        address = address + modified_data[i]["門牌"][0][k]
  #print("{}:".format(i)+address)

# %% [markdown]
# ## 經緯度爬蟲

# %%
options = webdriver.ChromeOptions()
options.add_argument("headless")
def get_coordinate(addr):
    browser = webdriver.Chrome(executable_path='chromedriver',options=options)
    browser.get("http://www.map.com.tw/")
    search = browser.find_element_by_id("searchWord")
    search.clear()
    search.send_keys(addr)
    browser.find_element_by_xpath("/html/body/form/div[10]/div[2]/img[2]").click() 
    time.sleep(1)
    iframe = browser.find_elements_by_tag_name("iframe")[1]
    browser.switch_to.frame(iframe)
    coor_btn = browser.find_element_by_xpath("/html/body/form/div[4]/table/tbody/tr[3]/td/table/tbody/tr/td[2]")
    coor_btn.click()
    coor = browser.find_element_by_xpath("/html/body/form/div[5]/table/tbody/tr[2]/td")
    coor = coor.text.strip().split(" ")
    lat = coor[-1].split("：")[-1]
    log = coor[0].split("：")[-1]
    browser.quit()
    return "{},{}".format(lat, log)

# %% [markdown]
# #### 地址測試

# %%
get_coordinate("台北市大安區羅斯福路四段1號")
# Out:
# '25.017049,121.533648'

# %% [markdown]
# ### 實際爬蟲

# %%
for i in range(0,count):
    address = ""
    for k in key:
        address = address + modified_data[i]["門牌"][0][k]
    try:
        modified_data[i]["經緯"] = get_coordinate(address)
    except:
        pass
    clear_output(wait=True)
    print("{} / {}".format(i,count))
# Out:
# 837 / 838

# %%
for i in range(0,count):
    try:
        #pass
        print(modified_data[i]["經緯"])
    except:
        print("NAN")
# Out:
# 23.497119,120.377328
# 23.431966,120.473402
# 23.608559,120.401166
# 23.455441,120.190345
# 23.513363,120.372111
# 23.577768,120.748588
# 23.56936835,120.4944118
# 23.527109,120.456244
# 23.531685,120.43428
# 23.549662,120.427352
# 23.458758,120.293862
# 23.519787,120.455639
# 23.523599,120.581451
# 23.436083,120.19589
# 23.597782,120.521187
# 23.598065,120.520208
# 23.549557,120.42733
# 23.47467335,120.71335839
# 23.554669,120.299454
# 23.527109,120.456244
# 23.503699,120.365024
# 23.449622,120.265063
# 23.520019,120.351001
# 23.373361,120.505939
# 25.05475,121.222742
# 23.453299,120.244662
# 23.478892,120.212586
# NAN
# 23.521179,120.250028
# 23.521119,120.250015
# 23.521061,120.25
# 23.604325,120.394045
# 23.478733,120.561351
# 23.447666,120.455075
# 23.399388,120.512441
# 23.446322,120.511639
# 23.534336,120.301795
# 23.534332,120.302045
# 23.519135,120.353854
# 23.602039,120.439332
# 23.596134,120.510702
# 23.629541,120.487931
#  '地上層數': '2層',
#  '地下層數': '0層',
#  '棟數': '1棟',
#  '戶數': '1戶',
#  '起造人代表人': '翁嘉Ｏ',
#  '設計人': '吳德Ｏ',
#  '監造人': '',
#  '承造人': '',
#  '雜項工作物': '圍牆工程造價36000元。',
#  '停車空間': '法定2輛，獎勵0輛，自設0輛',
#  '發照日期': '107年09月25日',
#  '實際開工日期': '',
#  '竣工日期': '',
#  'qtime': '1070925',
#  '樓層概要': [{'樓層別': '', '樓層高度': '3.4ｍ', '樓層面積': '62.57㎡', '樓層用途': 'H2住宅'},
#   {'樓層別': '', '樓層高度': '4.0ｍ', '樓層面積': '96.61㎡', '樓層用途': 'H2住宅'}],
#  '地號': [{'行政區': '嘉義縣水上鄉', '地段': '三界埔段', '地號母號': '0409', '地號子號': '0014'}],
#  '門牌': [{'戶號': '',
#    '行政區': '嘉義縣水上鄉',
#    '村里鄰': '三界村',
#    '路街段巷弄': '三界埔',
#    '號': '172號之1',
#    '樓': ''}],
#  '經緯': '23.431966,120.473402'}

# %%
for building in modified_data:
    key = ['行政區','村里鄰','路街段巷弄','號','樓']
    address = ""
    for k in key:
        address = address + building["門牌"][0][k]
    building["地址"]= address
with open(filename[:-5]+"_modified.json", "w") as f:
    f.write(json.dumps(modified_data))

# %%
import json
building_position = []
geojson = {"type": "FeatureCollection","features":[]}
with open(filename[:-5]+"_modified.json", "r") as f:
    JSON_file = json.load(f)
    
    for item in JSON_file:
        try:
            feature= {
                  "type": "Feature",
                  "geometry" : {
                      "type": "Point",
                      "coordinates": [item["經緯"].split(",")[1],item["經緯"].split(",")[0]]
                      },
                  "properties" : item,
            }
            geojson["features"].append(feature)
        except:
            pass
len(geojson["features"])

with open(filename[:-5]+"_geo.json","w") as f:
    f.write(json.dumps(geojson))

# %%
import folium
from folium.plugins import MarkerCluster, Search
import geopandas
from json2html import *
Taiwan_building_map = folium.Map(location=[23.58,121], zoom_start=7)
geojson = {"type": "FeatureCollection","features":[]}
with open(filename[:-5]+"_geo.json", "r") as f:
    JSON_file = json.load(f)
building= geopandas.read_file(filename[:-5]+"_geo.json")
addressgeo = folium.GeoJson(
    JSON_file,
    name='建築位置',
    show=False
).add_to(Taiwan_building_map)

statesearch = Search(
    layer=addressgeo,
    geom_type='Points',
    placeholder='搜尋地址',
    collapsed=False,
    search_label='地址',
    search_zoom=17,
    weight=3,
    #tooltip=folium.GeoJsonTooltip(fields=["地址"],aliases=["地址"])
).add_to(Taiwan_building_map)

marker_cluster = MarkerCluster(name="建築標記").add_to(Taiwan_building_map)
address_list=[]

for i in range(len(building)):
    try:
        popuptext = "<h4>{}</h4>{}".format(JSON_file["features"][i]["properties"]["地址"]
                                           ,json2html.convert(json = JSON_file["features"][i]["properties"]["樓層概要"]))
    except:
        popuptext = "<h4>{}</h4>".format(JSON_file["features"][i]["properties"]["地址"])
    test = folium.Html(popuptext, script=True)
    popup = folium.Popup(test, max_width=300,min_width=300)
    folium.Marker(
      popup = popup,
      location=[building["經緯"].values[i].split(",")[0],building["經緯"].values[i].split(",")[1]],
      icon=None).add_to(marker_cluster)
    
folium.LayerControl().add_to(Taiwan_building_map)
Taiwan_building_map.save('Folium_測試.html')
